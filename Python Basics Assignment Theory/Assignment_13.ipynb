# %% [markdown]
# # Assignment 13

# %% [markdown]
# #### 1. What advantages do Excel spreadsheets have over CSV spreadsheets?
# **Ans:** The Advantages of Excel over CSV are:
# 1. Excel (XLS and XLSX) file formats are better for storing and analysing complex data.
# 2. An Excel not only stores data but can also do operations on the data using macros, formulas etc
# 3. CSV files are plain-text files, Does not contain formatting, formulas, macros, etc. It is also known as flat files

# %% [markdown]
# #### 2.What do you pass to csv.reader() and csv.writer() to create reader and writer objects?

# %%
import csv
with open('data.csv','r') as file:
    csv_file = csv.reader(file,delimiter=',')
    for ele in csv_file:
        print(ele)
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver', 'day', 'month', 'year']
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19000.0', '10000', 'Free', '0.0', 'Everyone', 'Art & Design', '2018-01-07', '1.0.0', '4.0.3 ', '7', '1', '2018']
# ['Coloring book moana', 'ART_AND_DESIGN', '3.9', '967', '14000.0', '500000', 'Free', '0.0', 'Everyone', 'Art & Design;Pretend Play', '2018-01-15', '2.0.0', '4.0.3 ', '15', '1', '2018']
# ['U Launcher Lite â€“ FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8700.0', '5000000', 'Free', '0.0', 'Everyone', 'Art & Design', '2018-08-01', '1.2.4', '4.0.3 ', '1', '8', '2018']
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25000.0', '50000000', 'Free', '0.0', 'Teen', 'Art & Design', '2018-06-08', 'Varies with device', '4.2 ', '8', '6', '2018']
# ['Pixel Draw - Number Art Coloring Book', 'ART_AND_DESIGN', '4.3', '967', '2800.0', '100000', 'Free', '0.0', 'Everyone', 'Art & Design;Creativity', '2018-06-20', '1.1', '4.4 ', '20', '6', '2018']
# ['Paper flowers instructions', 'ART_AND_DESIGN', '4.4', '167', '5600.0', '50000', 'Free', '0.0', 'Everyone', 'Art & Design', '2017-03-26', '1.0', '2.3 ', '26', '3', '2017']
# ['Smoke Effect Photo Maker - Smoke Editor', 'ART_AND_DESIGN', '3.8', '178', '19000.0', '50000', 'Free', '0.0', 'Everyone', 'Art & Design', '2018-04-26', '1.1', '4.0.3 ', '26', '4', '2018']
# ['Infinite Painter', 'ART_AND_DESIGN', '4.1', '36815', '29000.0', '1000000', 'Free', '0.0', 'Everyone', 'Art & Design', '2018-06-14', '6.1.61.1', '4.2 ', '14', '6', '2018']
# ['Garden Coloring Book', 'ART_AND_DESIGN', '4.4', '13791', '33000.0', '1000000', 'Free', '0.0', 'Everyone', 'Art & Design', '2017-09-20', '2.9.2', '3.0 ', '20', '9', '2017']
# ['Kids Paint Free - Drawing Fun', 'ART_AND_DESIGN', '4.7', '121', '3100.0', '10000', 'Free', '0.0', 'Everyone', 'Art & Design;Creativity', '2018-07-03', '2.8', '4.0.3 ', '3', '7', '2018']
# ['Text on Photo - Fonteee', 'ART_AND_DESIGN', '4.4', '13880', '28000.0', '1000000', 'Free', '0.0', 'Everyone', 'Art & Design', '2017-10-27', '1.0.4', '4.1 ', '27', '10', '2017']
# ['Name Art Photo Editor - Focus n Filters', 'ART_AND_DESIGN', '4.4', '8788', '12000.0', '1000000', 'Free', '0.0', 'Everyone', 'Art & Design', '2018-07-31', '1.0.15', '4.0 ', '31', '7', '2018']
# ['Tattoo Name On My Photo Editor', 'ART_AND_DESIGN', '4.2', '44829', '20000.0', '10000000', 'Free', '0.0', 'Teen', 'Art & Design', '2018-04-02', '3.8', '4.1 ', '2', '4', '2018']
# ['Mandala Coloring Book', 'ART_AND_DESIGN', '4.6', '4326', '21000.0', '100000', 'Free', '0.0', 'Everyone', 'Art & Design', '2018-06-26', '1.0.4', '4.4 ', '26', '6', '2018']
# ['3D Color Pixel by Number - Sandbox Art Coloring', 'ART_AND_DESIGN', '4.4', '1518', '37000.0', '100000', 'Free', '0.0', 'Everyone', 'Art & Design', '2018-08-03', '1.2.3', '2.3 ', '3', '8', '2018']
# ['Photo Designer - Write your name with shapes', 'ART_AND_DESIGN', '4.7', '3632', '5500.0', '500000', 'Free', '0.0', 'Everyone', 'Art & Design', '2018-07-31', '3.1', '4.1 ', '31', '7', '2018']
# ['350 Diy Room Decor Ideas', 'ART_AND_DESIGN', '4.5', '27', '17000.0', '10000', 'Free', '0.0', 'Everyone', 'Art & Design', '2017-11-07', '1.0', '2.3 ', '7', '11', '2017']
# ['FlipaClip - Cartoon animation', 'ART_AND_DESIGN', '4.3', '194216', '39000.0', '5000000', 'Free', '0.0', 'Everyone', 'Art & Design', '2018-08-03', '2.2.5', '4.0.3 ', '3', '8', '2018']
# ['ibis Paint X', 'ART_AND_DESIGN', '4.6', '224399', '31000.0', '10000000', 'Free', '0.0', 'Everyone', 'Art & Design', '2018-07-30', '5.5.4', '4.1 ', '30', '7', '2018']
# ['Logo Maker - Small Business', 'ART_AND_DESIGN', '4.0', '450', '14000.0', '100000', 'Free', '0.0', 'Everyone', 'Art & Design', '2018-04-20', '4.0', '4.1 ', '20', '4', '2018']
# ["Boys Photo Editor - Six Pack & Men's Suit", 'ART_AND_DESIGN', '4.1', '654', '12000.0', '100000', 'Free', '0.0', 'Everyone', 'Art & Design', '2018-03-20', '1.1', '4.0.3 ', '20', '3', '2018']
# ['Superheroes Wallpapers | 4K Backgrounds', 'ART_AND_DESIGN', '4.7', '7699', '4200.0', '500000', 'Free', '0.0', 'Everyone 10+', 'Art & Design', '2018-07-12', '2.2.6.2', '4.0.3 ', '12', '7', '2018']
# ['HD Mickey Minnie Wallpapers', 'ART_AND_DESIGN', '4.7', '118', '23000.0', '50000', 'Free', '0.0', 'Everyone', 'Art & Design', '2018-07-07', '1.1.3', '4.1 ', '7', '7', '2018']
# ['Harley Quinn wallpapers HD', 'ART_AND_DESIGN', '4.8', '192', '6000.0', '10000', 'Free', '0.0', 'Everyone', 'Art & Design', '2018-04-25', '1.5', '3.0 ', '25', '4', '2018']
# ['Colorfit - Drawing & Coloring', 'ART_AND_DESIGN', '4.7', '20260', '25000.0', '500000', 'Free', '0.0', 'Everyone', 'Art & Design;Creativity', '2017-10-11', '1.0.8', '4.0.3 ', '11', '10', '2017']
# ['Animated Photo Editor', 'ART_AND_DESIGN', '4.1', '203', '6100.0', '100000', 'Free', '0.0', 'Everyone', 'Art & Design', '2018-03-21', '1.03', '4.0.3 ', '21', '3', '2018']
# ['Pencil Sketch Drawing', 'ART_AND_DESIGN', '3.9', '136', '4600.0', '10000', 'Free', '0.0', 'Everyone', 'Art & Design', '2018-07-12', '6.0', '2.3 ', '12', '7', '2018']
# ['Easy Realistic Drawing Tutorial', 'ART_AND_DESIGN', '4.1', '223', '4200.0', '100000', 'Free', '0.0', 'Everyone', 'Art & Design', '2017-08-22', '1.0', '2.3 ', '22', '8', '2017']
# ['Pink Silver Bow Keyboard Theme', 'ART_AND_DESIGN', '4.2', '1120', '9200.0', '100000', 'Free', '0.0', 'Everyone', 'Art & Design', '2018-07-12', '6.7.12.2018', '4.0.3 ', '12', '7', '2018']
# ['Art Drawing Ideas', 'ART_AND_DESIGN', '4.1', '227', '5200.0', '50000', 'Free', '0.0', 'Everyone', 'Art & Design', '2018-05-31', '1.2', '2.3 ', '31', '5', '2018']
# ['Anime Manga Coloring Book', 'ART_AND_DESIGN', '4.5', '5035', '11000.0', '100000', 'Free', '0.0', 'Everyone', 'Art & Design', '2018-07-19', '2.20', '4.0 ', '19', '7', '2018']
# ['Easy Origami Ideas', 'ART_AND_DESIGN', '4.2', '1015', '11000.0', '100000', 'Free', '0.0', 'Everyone', 'Art & Design', '2018-01-06', '1.1.0', '4.1 ', '6', '1', '2018']
# ['I Creative Idea', 'ART_AND_DESIGN', '4.7', '353', '4200.0', '10000', 'Free', '0.0', 'Teen', 'Art & Design', '2018-04-27', '1.6', '4.1 ', '27', '4', '2018']
# ['How to draw Ladybug and Cat Noir', 'ART_AND_DESIGN', '3.8', '564', '9200.0', '100000', 'Free', '0.0', 'Everyone', 'Art & Design', '2018-07-11', '2.1', '4.1 ', '11', '7', '2018']
# ['UNICORN - Color By Number & Pixel Art Coloring', 'ART_AND_DESIGN', '4.7', '8145', '24000.0', '500000', 'Free', '0.0', 'Everyone', 'Art & Design;Creativity', '2018-08-02', '1.0.9', '4.4 ', '2', '8', '2018']
# ['PIP Camera - PIP Collage Maker', 'ART_AND_DESIGN', '4.7', '158', '11000.0', '10000', 'Free', '0.0', 'Everyone', 'Art & Design', '2017-11-29', '1.3', '4.0.3 ', '29', '11', '2017']
# ['How To Color Disney Princess - Coloring Pages', 'ART_AND_DESIGN', '4.0', '591', '9400.0', '500000', 'Free', '0.0', 'Everyone', 'Art & Design', '2018-03-31', '1', '4.0 ', '31', '3', '2018']
# ['Drawing Clothes Fashion Ideas', 'ART_AND_DESIGN', '4.2', '117', '15000.0', '10000', 'Free', '0.0', 'Everyone', 'Art & Design', '2018-07-20', '2.0.1', '4.0.3 ', '20', '7', '2018']
# ['Sad Poetry Photo Frames 2018', 'ART_AND_DESIGN', '4.5', '176', '10000.0', '100000', 'Free', '0.0', 'Everyone', 'Art & Design', '2018-04-02', '1.0', '4.0.3 ', '2', '4', '2018']
# ['Paint Splash!', 'ART_AND_DESIGN', '3.8', '2206', '1200.0', '100000', 'Free', '0.0', 'Everyone', 'Art & Design;Creativity', '2018-04-15', '1.46', '4.1 ', '15', '4', '2018']
# ['Popsicle Sticks and Similar DIY Craft Ideas', 'ART_AND_DESIGN', '4.2', '26', '12000.0', '10000', 'Free', '0.0', 'Everyone', 'Art & Design', '2018-01-03', '1.0.0', '4.1 ', '3', '1', '2018']
# ['Canva: Poster, banner, card maker & graphic design', 'ART_AND_DESIGN', '4.7', '174531', '24000.0', '10000000', 'Free', '0.0', 'Everyone', 'Art & Design', '2018-07-31', '1.6.1', '4.1 ', '31', '7', '2018']
# ['Install images with music to make video without Net - 2018', 'ART_AND_DESIGN', '4.6', '1070', '26000.0', '100000', 'Free', '0.0', 'Everyone', 'Art & Design', '2017-11-14', '1.6', '4.1 ', '14', '11', '2017']
# ['Little Teddy Bear Colouring Book Game', 'ART_AND_DESIGN', '4.2', '85', '8000.0', '100000', 'Free', '0.0', 'Everyone', 'Art & Design', '2017-12-17', '2.0.0', '4.1 ', '17', '12', '2017']
# ['How To Draw Food', 'ART_AND_DESIGN', '4.3', '845', '7900.0', '100000', 'Free', '0.0', 'Everyone', 'Art & Design', '2018-05-28', '1.0', '2.3 ', '28', '5', '2018']
# ['Monster Truck Stunt 3D 2019', 'AUTO_AND_VEHICLES', '4.2', '367', '25000.0', '100000', 'Free', '0.0', 'Everyone', 'Auto & Vehicles', '2018-05-10', '1.0', '4.0.3 ', '10', '5', '2018']
# ['Real Tractor Farming', 'AUTO_AND_VEHICLES', '4.0', '1598', '56000.0', '1000000', 'Free', '0.0', 'Everyone', 'Auto & Vehicles', '2018-07-26', '11.0', '4.1 ', '26', '7', '2018']
# ['Ultimate F1 Racing Championship', 'AUTO_AND_VEHICLES', '3.8', '284', '57000.0', '100000', 'Free', '0.0', 'Everyone', 'Auto & Vehicles', '2018-07-26', '3.0', '4.1 ', '26', '7', '2018']
# ['American Muscle Car Race', 'AUTO_AND_VEHICLES', '3.9', '129', '35000.0', '100000', 'Free', '0.0', 'Everyone', 'Auto & Vehicles', '2018-07-26', '3.0', '4.1 ', '26', '7', '2018']
# ['Offroad Oil Tanker Driver Transport Truck 2019', 'AUTO_AND_VEHICLES', '4.3', '542', '33000.0', '100000', 'Free', '0.0', 'Everyone', 'Auto & Vehicles', '2018-07-31', '4.0', '4.1 ', '31', '7', '2018']
# ['Tickets SDA 2018 and Exam from the State Traffic Safety Inspectorate with Drom.ru', 'AUTO_AND_VEHICLES', '4.9', '10479', '33000.0', '100000', 'Free', '0.0', 'Everyone', 'Auto & Vehicles', '2018-07-18', '1.7.1', '4.0 ', '18', '7', '2018']
# ['Gas Prices (Germany only)', 'AUTO_AND_VEHICLES', '4.4', '805', '5600.0', '50000', 'Free', '0.0', 'Everyone', 'Auto & Vehicles', '2018-07-29', '2.5.1', '4.4 ', '29', '7', '2018']
# ['Extreme Rally Championship', 'AUTO_AND_VEHICLES', '4.2', '129', '54000.0', '100000', 'Free', '0.0', 'Everyone', 'Auto & Vehicles', '2018-07-26', '3.0', '4.1 ', '26', '7', '2018']
# ['Restart Navigator', 'AUTO_AND_VEHICLES', '4.0', '1403', '201.0', '100000', 'Free', '0.0', 'Everyone', 'Auto & Vehicles', '2014-08-26', '1.0.1', '2.2 ', '26', '8', '2014']
# ['REG - Check the regnumber, find information about Swedish vehicles', 'AUTO_AND_VEHICLES', '3.9', '3971', '3600.0', '100000', 'Free', '0.0', 'Everyone', 'Auto & Vehicles', '2018-07-30', '2.493', '4.4 ', '30', '7', '2018']
# ['CityBus Lviv', 'AUTO_AND_VEHICLES', '4.6', '534', '5700.0', '10000', 'Free', '0.0', 'Everyone', 'Auto & Vehicles', '2018-07-08', '1.9.1', '4.0.3 ', '8', '7', '2018']
# ['CDL Practice Test 2018 Edition', 'AUTO_AND_VEHICLES', '4.9', '7774', '17000.0', '100000', 'Free', '0.0', 'Everyone', 'Auto & Vehicles', '2018-07-03', '1.7', '4.2 ', '3', '7', '2018']
# ['ezETC (ETC balance inquiry, meter trial, real-time traffic)', 'AUTO_AND_VEHICLES', '4.3', '38846', '8600.0', '1000000', 'Free', '0.0', 'Everyone', 'Auto & Vehicles', '2018-07-28', '2.20 Build 02', '4.1 ', '28', '7', '2018']
# ['Free VIN Report for Used Cars', 'AUTO_AND_VEHICLES', '4.6', '2431', '2400.0', '100000', 'Free', '0.0', 'Everyone', 'Auto & Vehicles', '2018-06-12', '1.37', '4.0 ', '12', '6', '2018']
# ['DMV Permit Practice Test 2018 Edition', 'AUTO_AND_VEHICLES', '4.9', '6090', '27000.0', '100000', 'Free', '0.0', 'Everyone', 'Auto & Vehicles', '2018-07-03', '1.7', '4.2 ', '3', '7', '2018']
# ['Check Vehicle Tax', 'AUTO_AND_VEHICLES', '3.9', '295', '2700.0', '10000', 'Free', '0.0', 'Everyone', 'Auto & Vehicles', '2018-07-30', '0.2.1', '4.4 ', '30', '7', '2018']
# ['Used Cars Mexico', 'AUTO_AND_VEHICLES', '4.0', '190', '2500.0', '50000', 'Free', '0.0', 'Everyone', 'Auto & Vehicles', '2016-10-14', '1.0', '2.3 ', '14', '10', '2016']
# ['Used cars for sale - Trovit', 'AUTO_AND_VEHICLES', '4.2', '52530', '7000.0', '5000000', 'Free', '0.0', 'Everyone', 'Auto & Vehicles', '2018-07-16', '4.47.3', '4.0.3 ', '16', '7', '2018']
# ['Fines of the State Traffic Safety Inspectorate are official: inspection, payment of fines', 'AUTO_AND_VEHICLES', '4.8', '116986', '35000.0', '5000000', 'Free', '0.0', 'Everyone', 'Auto & Vehicles', '2018-08-02', '1.9.7', '4.0.3 ', '2', '8', '2018']
# ['SK Enca Direct Malls - Used Cars Search', 'AUTO_AND_VEHICLES', '3.6', '1379', '16000.0', '500000', 'Free', '0.0', 'Everyone', 'Auto & Vehicles', '2018-08-02', '2.2.21', '4.2 ', '2', '8', '2018']
# ['Android Auto - Maps, Media, Messaging & Voice', 'AUTO_AND_VEHICLES', '4.2', '271920', '16000.0', '10000000', 'Free', '0.0', 'Teen', 'Auto & Vehicles', '2018-07-11', 'Varies with device', '5.0 ', '11', '7', '2018']
# ['Tickets SDA 2019 + Exam RF', 'AUTO_AND_VEHICLES', '4.8', '7021', '17000.0', '500000', 'Free', '0.0', 'Everyone', 'Auto & Vehicles', '2018-07-27', '1.79', '4.0 ', '27', '7', '2018']
# ['Super Cars Wallpapers And Backgrounds', 'AUTO_AND_VEHICLES', '4.6', '197', '3400.0', '50000', 'Free', '0.0', 'Everyone', 'Auto & Vehicles', '2018-06-14', '1.3', '4.0 ', '14', '6', '2018']
# ['Police Lights, Sirens & Follow Me', 'AUTO_AND_VEHICLES', '4.5', '737', '8900.0', '100000', 'Free', '0.0', 'Everyone', 'Auto & Vehicles', '2018-06-08', '2.3.5.1', '4.1 ', '8', '6', '2018']
# ['Police Detector (Speed Camera Radar)', 'AUTO_AND_VEHICLES', '4.3', '3574', '3900.0', '1000000', 'Free', '0.0', 'Everyone 10+', 'Auto & Vehicles', '2018-07-04', '1.6', '4.0 ', '4', '7', '2018']
# ['Best Car Wallpapers', 'AUTO_AND_VEHICLES', '4.5', '994', '2900.0', '100000', 'Free', '0.0', 'Everyone', 'Auto & Vehicles', '2018-03-27', '1.6', '4.1 ', '27', '3', '2018']
# ['Tickets + PDA 2018 Exam', 'AUTO_AND_VEHICLES', '4.9', '197136', '38000.0', '1000000', 'Free', '0.0', 'Everyone', 'Auto & Vehicles', '2018-07-15', '8.31', '4.1 ', '15', '7', '2018']
# ['Pick Your Part Garage', 'AUTO_AND_VEHICLES', '3.9', '142', '32000.0', '50000', 'Free', '0.0', 'Everyone', 'Auto & Vehicles', '2018-07-24', '1.1.5.0', '6.0 ', '24', '7', '2018']
# ['PakWheels: Buy & Sell Cars', 'AUTO_AND_VEHICLES', '4.4', '15168', '37000.0', '1000000', 'Free', '0.0', 'Everyone', 'Auto & Vehicles', '2018-07-27', '10.0.2', '4.2 ', '27', '7', '2018']
# ['Supervision service', 'AUTO_AND_VEHICLES', '4.0', '2155', '15000.0', '500000', 'Free', '0.0', 'Everyone', 'Auto & Vehicles', '2018-07-30', '1.10.3', '5.0 ', '30', '7', '2018']
# ['Speed Camera Detector - Traffic & Speed Alert', 'AUTO_AND_VEHICLES', '4.3', '138', '5400.0', '100000', 'Free', '0.0', 'Everyone', 'Auto & Vehicles', '2018-07-23', '1.0', '4.0.3 ', '23', '7', '2018']
# ['Used car search Goo net whole car Go to net', 'AUTO_AND_VEHICLES', '3.7', '5414', '18000.0', '1000000', 'Free', '0.0', 'Everyone', 'Auto & Vehicles', '2018-07-23', '3.20.1', '4.4 ', '23', '7', '2018']
# ['BEST CAR SOUNDS', 'AUTO_AND_VEHICLES', '4.3', '348', '38000.0', '100000', 'Free', '0.0', 'Everyone', 'Auto & Vehicles', '2018-07-29', '1.0.3', '2.3 ', '29', '7', '2018']
# ['RST - Sale of cars on the PCT', 'AUTO_AND_VEHICLES', '3.2', '250', '1100.0', '100000', 'Free', '0.0', 'Everyone', 'Auto & Vehicles', '2018-04-27', '1.4', '4.0.3 ', '27', '4', '2018']
# ['SMS Park', 'AUTO_AND_VEHICLES', '4.5', '3617', '7900.0', '100000', 'Free', '0.0', 'Everyone', 'Auto & Vehicles', '2018-05-16', '2.8.2', '4.1 ', '16', '5', '2018']
# ['SKencar', 'AUTO_AND_VEHICLES', '3.7', '4806', '35000.0', '1000000', 'Free', '0.0', 'Everyone', 'Auto & Vehicles', '2018-07-31', '4.0.3', '4.0.3 ', '31', '7', '2018']
# ['auto fines', 'AUTO_AND_VEHICLES', '4.6', '31433', '17000.0', '1000000', 'Free', '0.0', 'Everyone', 'Auto & Vehicles', '2018-08-02', '1.40', '4.0.3 ', '2', '8', '2018']
# ['Used car is the first car - used car purchase, used car quotation, dealer information to', 'AUTO_AND_VEHICLES', '4.6', '5097', '19000.0', '1000000', 'Free', '0.0', 'Everyone', 'Auto & Vehicles', '2018-07-23', '1.5.18', '4.0.3 ', '23', '7', '2018']
# ['All of the parking lot - National Park application (parking lot search / parking sharing / discount payment)', 'AUTO_AND_VEHICLES', '4.0', '1754', '14000.0', '500000', 'Free', '0.0', 'Everyone', 'Auto & Vehicles', '2018-06-02', '2.3.4', '4.0 ', '2', '6', '2018']
# ['Inquiry Fines and Debits of Vehicles', 'AUTO_AND_VEHICLES', '4.4', '2680', '2200.0', '500000', 'Free', '0.0', 'Everyone', 'Auto & Vehicles', '2018-03-20', '1.03', '4.0.3 ', '20', '3', '2018']
# ['Gas Station', 'AUTO_AND_VEHICLES', '4.0', '1288', '4500.0', '100000', 'Free', '0.0', 'Everyone', 'Auto & Vehicles', '2018-04-21', '2.17', '4.0 ', '21', '4', '2018']
# ['Hush - Beauty for Everyone', 'BEAUTY', '4.7', '18900', '17000.0', '500000', 'Free', '0.0', 'Everyone', 'Beauty', '2018-08-02', '6.10.1', '5.0 ', '2', '8', '2018']
# ['ipsy: Makeup, Beauty, and Tips', 'BEAUTY', '4.9', '49790', '14000.0', '1000000', 'Free', '0.0', 'Everyone', 'Beauty', '2017-11-09', '2.3.0', '4.1 ', '9', '11', '2017']
# ['Natural recipes for your beauty', 'BEAUTY', '4.7', '1150', '9800.0', '100000', 'Free', '0.0', 'Everyone', 'Beauty', '2018-05-15', '4.0', '4.1 ', '15', '5', '2018']
# ['BestCam Selfie-selfie, beauty camera, photo editor', 'BEAUTY', '3.9', '1739', '21000.0', '500000', 'Free', '0.0', 'Everyone', 'Beauty', '2018-07-12', '1.0.6', '4.0.3 ', '12', '7', '2018']
# ['Beauty Selfie Camera', 'BEAUTY', '4.2', '2225', '52000.0', '500000', 'Free', '0.0', 'Everyone', 'Beauty', '2018-02-28', '1.6', '4.1 ', '28', '2', '2018']
# ['Hairstyles step by step', 'BEAUTY', '4.6', '4369', '14000.0', '100000', 'Free', '0.0', 'Everyone', 'Beauty', '2018-07-25', '1.9', '4.0.3 ', '25', '7', '2018']
# ['Filters for Selfie', 'BEAUTY', '4.3', '8572', '25000.0', '1000000', 'Free', '0.0', 'Everyone', 'Beauty', '2018-05-10', '1.1.0', '4.0 ', '10', '5', '2018']
# ['Tie - Always be happy', 'BEAUTY', '4.7', '964', '9000.0', '50000', 'Free', '0.0', 'Everyone', 'Beauty', '2018-06-21', '4.0', '4.2 ', '21', '6', '2018']
# ['Prom MakeUp Tutorial', 'BEAUTY', '4.8', '104', '12000.0', '10000', 'Free', '0.0', 'Everyone', 'Beauty', '2018-06-26', '1.3', '4.0.3 ', '26', '6', '2018']
# ['Sweet Selfie Beauty Camera', 'BEAUTY', '4.3', '601', '35000.0', '100000', 'Free', '0.0', 'Everyone', 'Beauty', '2018-06-02', '2.0.0', '4.0 ', '2', '6', '2018']
# ['Colors of white in Urdu', 'BEAUTY', '4.5', '36', '6700.0', '10000', 'Free', '0.0', 'Everyone', 'Beauty', '2018-07-26', '6.0', '4.0 ', '26', '7', '2018']
# ['Selfie Camera Photo Editor & Filter & Sticker', 'BEAUTY', '4.1', '187', '30000.0', '50000', 'Free', '0.0', 'Teen', 'Beauty', '2018-07-24', '3.0.1', '4.0.3 ', '24', '7', '2018']
# ['Eyes Makeup Beauty Tips', 'BEAUTY', '4.2', '30', '2900.0', '10000', 'Free', '0.0', 'Everyone', 'Beauty', '2018-04-09', '3.3.9', '4.0.3 ', '9', '4', '2018']
# ['Photo Editor 2018', 'BEAUTY', '4.5', '134', '17000.0', '10000', 'Free', '0.0', 'Everyone', 'Beauty', '2018-03-01', '1.20', '4.0.3 ', '1', '3', '2018']
# ['Step By Step Eyes Makeup Tutorial', 'BEAUTY', '4.4', '74', '2900.0', '10000', 'Free', '0.0', 'Everyone', 'Beauty', '2018-04-05', '2.3.09', '4.0.3 ', '5', '4', '2018']
# ['Mirror Camera (Mirror + Selfie Camera)', 'BEAUTY', '4.1', '9315', '2600.0', '1000000', 'Free', '0.0', 'Everyone', 'Beauty', '2017-11-21', '1.4.2', '4.0 ', '21', '11', '2017']
# ['Beauty Tips - Beauty Tips in Sinhala', 'BEAUTY', '4.4', '75', '4200.0', '50000', 'Free', '0.0', 'Everyone', 'Beauty', '2017-10-18', '1.0.0', '4.0.3 ', '18', '10', '2017']
# ['Haircut Tutorials/Haircut Videos', 'BEAUTY', '4.6', '38', '7100.0', '10000', 'Free', '0.0', 'Everyone', 'Beauty', '2018-05-29', '1.0', '4.0 ', '29', '5', '2018']
# ['Sephora: Skin Care, Beauty Makeup & Fragrance Shop', 'BEAUTY', '4.5', '26834', '57000.0', '1000000', 'Free', '0.0', 'Everyone', 'Beauty', '2018-07-24', '18.5', '5.0 ', '24', '7', '2018']
# ['Sticker Camera - Selfie Filters, Beauty Camera', 'BEAUTY', '3.9', '2277', '22000.0', '500000', 'Free', '0.0', 'Everyone', 'Beauty', '2018-07-12', '1.1.0', '4.0.3 ', '12', '7', '2018']
# ['Filters for B Live', 'BEAUTY', '4.4', '2280', '24000.0', '500000', 'Free', '0.0', 'Everyone', 'Beauty', '2018-05-14', '1.1.0', '4.0 ', '14', '5', '2018']
# ['Facial Wrinkle Reduction', 'BEAUTY', '4.6', '184', '21000.0', '10000', 'Free', '0.0', 'Everyone', 'Beauty', '2018-07-02', '1.5', '4.1 ', '2', '7', '2018']
# ['Makeup Videos', 'BEAUTY', '3.8', '9', '3400.0', '5000', 'Free', '0.0', 'Everyone', 'Beauty', '2018-06-07', '1.0', '4.0 ', '7', '6', '2018']
# ['Discover Color', 'BEAUTY', '4.0', '364', '6400.0', '100000', 'Free', '0.0', 'Everyone', 'Beauty', '2018-05-24', '1.1', '4.0.3 ', '24', '5', '2018']
# ['Eyeliner step by step 2018', 'BEAUTY', '4.3', '18', '3200.0', '5000', 'Free', '0.0', 'Everyone', 'Beauty', '2018-06-01', '1.2.13', '4.0.3 ', '1', '6', '2018']
# ['Dresses Ideas & Fashions +3000', 'BEAUTY', '4.5', '473', '8200.0', '100000', 'Free', '0.0', 'Mature 17+', 'Beauty', '2017-03-01', '1.0.2.0', '1.6 ', '1', '3', '2017']
# ['Step By Step Hairstyles For Women', 'BEAUTY', '4.1', '66', '2900.0', '10000', 'Free', '0.0', 'Everyone', 'Beauty', '2018-04-05', '3.1.89', '4.0.3 ', '5', '4', '2018']
# ['Rainbow Camera', 'BEAUTY', '3.7', '3871', '23000.0', '1000000', 'Free', '0.0', 'Everyone', 'Beauty', '2018-07-30', '2.2.0', '4.0 ', '30', '7', '2018']
# ['Methods of teeth whitening', 'BEAUTY', '4.7', '257', '4600.0', '50000', 'Free', '0.0', 'Everyone', 'Beauty', '2017-08-07', '1.0', '4.0.3 ', '7', '8', '2017']
# ['Girls hairstyles 2018', 'BEAUTY', '4.2', '62', '3100.0', '10000', 'Free', '0.0', 'Everyone', 'Beauty', '2018-05-28', '1.9.2', '4.0.3 ', '28', '5', '2018']
# ['E-Book Read - Read Book for free', 'BOOKS_AND_REFERENCE', '4.5', '1857', '4900.0', '50000', 'Free', '0.0', 'Everyone', 'Books & Reference', '2018-08-03', '1.3.2', '4.4 ', '3', '8', '2018']
# ['Download free book with green book', 'BOOKS_AND_REFERENCE', '4.6', '4478', '9500.0', '100000', 'Free', '0.0', 'Everyone 10+', 'Books & Reference', '2017-07-31', '1.1', '4.0 ', '31', '7', '2017']
# ['Free Panda Radio Music', 'BOOKS_AND_REFERENCE', '4.5', '418', '4200.0', '100000', 'Free', '0.0', 'Everyone', 'Books & Reference', '2018-03-27', '2.1', '4.1 ', '27', '3', '2018']
# ['Book store', 'BOOKS_AND_REFERENCE', '4.4', '22486', '5400.0', '1000000', 'Free', '0.0', 'Teen', 'Books & Reference', '2018-06-06', '3.2.1', '4.0 ', '6', '6', '2018']
# ['English Grammar Complete Handbook', 'BOOKS_AND_REFERENCE', '4.6', '1435', '2800.0', '500000', 'Free', '0.0', 'Everyone', 'Books & Reference', '2018-01-21', '1.0', '4.0 ', '21', '1', '2018']
# ['Free Books - Spirit Fanfiction and Stories', 'BOOKS_AND_REFERENCE', '4.8', '116507', '5000.0', '1000000', 'Free', '0.0', 'Teen', 'Books & Reference', '2018-08-01', '2.0.075', '4.0.3 ', '1', '8', '2018']
# ['AlReader -any text book reader', 'BOOKS_AND_REFERENCE', '4.6', '90468', '5900.0', '5000000', 'Free', '0.0', 'Everyone', 'Books & Reference', '2018-05-27', '1.911805270', '2.3 ', '27', '5', '2018']
# ['Offline English Dictionary', 'BOOKS_AND_REFERENCE', '4.2', '860', '13000.0', '100000', 'Free', '0.0', 'Everyone', 'Books & Reference', '2018-07-17', '1.0', '4.0.3 ', '17', '7', '2018']
# ['Oxford Dictionary of English : Free', 'BOOKS_AND_REFERENCE', '4.1', '363934', '7100.0', '10000000', 'Free', '0.0', 'Everyone', 'Books & Reference', '2018-07-11', '9.1.363', '4.1 ', '11', '7', '2018']
# ['Offline: English to Tagalog Dictionary', 'BOOKS_AND_REFERENCE', '4.7', '967', '6700.0', '500000', 'Free', '0.0', 'Everyone', 'Books & Reference', '2018-08-04', '1.1.6', '4.0.3 ', '4', '8', '2018']
# ['FamilySearch Tree', 'BOOKS_AND_REFERENCE', '4.3', '17506', '17000.0', '1000000', 'Free', '0.0', 'Everyone', 'Books & Reference', '2018-07-20', '2.3.18', '4.1 ', '20', '7', '2018']
# ['Cloud of Books', 'BOOKS_AND_REFERENCE', '3.3', '1862', '19000.0', '1000000', 'Free', '0.0', 'Everyone', 'Books & Reference', '2018-04-27', '2.2.5', '4.1 ', '27', '4', '2018']
# ['Recipes of Prophetic Medicine for free', 'BOOKS_AND_REFERENCE', '4.6', '2084', '6700.0', '500000', 'Free', '0.0', 'Everyone', 'Books & Reference', '2018-05-17', '15.0', '2.3 ', '17', '5', '2018']
# ['ReadEra â€“ free ebook reader', 'BOOKS_AND_REFERENCE', '4.8', '47303', '21000.0', '1000000', 'Free', '0.0', 'Everyone', 'Books & Reference', '2018-06-02', '18.05.31+530', '4.1 ', '2', '6', '2018']
# ['Ebook Reader', 'BOOKS_AND_REFERENCE', '4.1', '85842', '37000.0', '5000000', 'Free', '0.0', 'Everyone', 'Books & Reference', '2018-06-25', '5.0.6', '4.0 ', '25', '6', '2018']
# ['Litnet - E-books', 'BOOKS_AND_REFERENCE', '4.6', '7831', '15000.0', '100000', 'Free', '0.0', 'Teen', 'Books & Reference', '2018-07-04', '1.2.3', '4.0 ', '4', '7', '2018']
# ['Read books online', 'BOOKS_AND_REFERENCE', '4.1', '91615', '23000.0', '5000000', 'Free', '0.0', 'Mature 17+', 'Books & Reference', '2018-06-29', '3.12', '4.1 ', '29', '6', '2018']
# ['English to Urdu Dictionary', 'BOOKS_AND_REFERENCE', '4.6', '4620', '19000.0', '500000', 'Free', '0.0', 'Everyone', 'Books & Reference', '2017-11-23', '2.0', '4.0.3 ', '23', '11', '2017']
# ['eBoox: book reader fb2 epub zip', 'BOOKS_AND_REFERENCE', '4.7', '21336', '23000.0', '1000000', 'Free', '0.0', 'Everyone', 'Books & Reference', '2018-06-20', '1.28', '3.0 ', '20', '6', '2018']
# ['English Persian Dictionary', 'BOOKS_AND_REFERENCE', '4.5', '26875', '73000.0', '500000', 'Free', '0.0', 'Everyone', 'Books & Reference', '2018-08-01', '6.0.8', '4.0.3 ', '1', '8', '2018']
# ['Flybook', 'BOOKS_AND_REFERENCE', '3.9', '1778', '4900.0', '500000', 'Free', '0.0', 'Mature 17+', 'Books & Reference', '2014-10-16', '1.0.3', '2.1 ', '16', '10', '2014']
# ['All Maths Formulas', 'BOOKS_AND_REFERENCE', '4.4', '2709', '6800.0', '1000000', 'Free', '0.0', 'Everyone', 'Books & Reference', '2018-07-11', '1.9', '4.4 ', '11', '7', '2018']
# ['English translation from Bengali', 'BOOKS_AND_REFERENCE', '4.5', '527', '2900.0', '100000', 'Free', '0.0', 'Everyone', 'Books & Reference', '2018-03-31', '14.0', '4.0 ', '31', '3', '2018']
# ['Pdf Book Download - Read Pdf Book', 'BOOKS_AND_REFERENCE', '4.4', '1322', '3500.0', '100000', 'Free', '0.0', 'Everyone', 'Books & Reference', '2018-05-28', '6.0', '4.0.3 ', '28', '5', '2018']
# ['Free Book Reader', 'BOOKS_AND_REFERENCE', '3.4', '1680', '4000.0', '100000', 'Free', '0.0', 'Everyone', 'Books & Reference', '2016-08-20', '3.05', '4.0.3 ', '20', '8', '2016']
# ['eBoox new: Reader for fb2 epub zip books', 'BOOKS_AND_REFERENCE', '4.9', '2739', '21000.0', '50000', 'Free', '0.0', 'Everyone', 'Books & Reference', '2018-07-17', '2.0', '3.0 ', '17', '7', '2018']
# ['Only 30 days in English, the guideline is guaranteed', 'BOOKS_AND_REFERENCE', '4.6', '1065', '2300.0', '500000', 'Free', '0.0', 'Everyone', 'Books & Reference', '2018-06-16', '1.5', '3.0 ', '16', '6', '2018']
# ['English-Myanmar Dictionary', 'BOOKS_AND_REFERENCE', '4.4', '8788', '10000.0', '1000000', 'Free', '0.0', 'Everyone', 'Books & Reference', '2018-07-28', '2.5.3', '4.0 ', '28', '7', '2018']
# ['Golden Dictionary (EN-AR)', 'BOOKS_AND_REFERENCE', '4.4', '51269', '6100.0', '1000000', 'Free', '0.0', 'Everyone', 'Books & Reference', '2018-07-19', '7.0.4.6', '4.2 ', '19', '7', '2018']
# ['All Language Translator Free', 'BOOKS_AND_REFERENCE', '4.4', '30105', '2100.0', '1000000', 'Free', '0.0', 'Everyone', 'Books & Reference', '2018-07-29', '1.15', '4.0.3 ', '29', '7', '2018']
# ['Azpen eReader', 'BOOKS_AND_REFERENCE', '3.5', '156', '42000.0', '500000', 'Free', '0.0', 'Everyone', 'Books & Reference', '2018-02-15', '3.1.7.9', '2.2 ', '15', '2', '2018']
# ['English Dictionary - Offline', 'BOOKS_AND_REFERENCE', '4.4', '341157', '30000.0', '10000000', 'Free', '0.0', 'Everyone 10+', 'Books & Reference', '2018-03-20', '3.9.1', '4.2 ', '20', '3', '2018']
# ['ADP Mobile Solutions', 'BUSINESS', '4.3', '85185', '29000.0', '5000000', 'Free', '0.0', 'Everyone', 'Business', '2018-07-17', '3.4.2', '5.0 ', '17', '7', '2018']
# ['OfficeSuite : Free Office + PDF Editor', 'BUSINESS', '4.3', '1002861', '35000.0', '100000000', 'Free', '0.0', 'Everyone', 'Business', '2018-08-02', '9.7.14188', '4.1 ', '2', '8', '2018']
# ['USPS MOBILEÂ®', 'BUSINESS', '3.9', '16589', '9100.0', '1000000', 'Free', '0.0', 'Everyone', 'Business', '2018-06-14', '4.9.10', '4.0.3 ', '14', '6', '2018']
# ['Job Search by ZipRecruiter', 'BUSINESS', '4.8', '148945', '25000.0', '1000000', 'Free', '0.0', 'Everyone', 'Business', '2018-07-19', '5.2.8', '5.0 ', '19', '7', '2018']
# ['Curriculum vitae App CV Builder Free Resume Maker', 'BUSINESS', '4.5', '4458', '3900.0', '500000', 'Free', '0.0', 'Everyone', 'Business', '2018-07-08', '3.3', '4.1 ', '8', '7', '2018']
# ['Google Primer', 'BUSINESS', '4.4', '62272', '18000.0', '10000000', 'Free', '0.0', 'Everyone', 'Business', '2018-06-26', '3.550.2', '4.1 ', '26', '6', '2018']
# ['Alba Heaven - Alvarez Job Portal Services', 'BUSINESS', '4.0', '8941', '12000.0', '5000000', 'Free', '0.0', 'Everyone', 'Business', '2018-07-31', '4.6.30', '4.0.3 ', '31', '7', '2018']
# ['SuperLivePro', 'BUSINESS', '4.3', '46353', '21000.0', '1000000', 'Free', '0.0', 'Everyone', 'Business', '2016-04-13', '2.8', '1.5 ', '13', '4', '2016']
# ['Polaris Office for LG', 'BUSINESS', '4.2', '30847', '55000.0', '5000000', 'Free', '0.0', 'Everyone', 'Business', '2018-02-08', '7.3.21', '4.1 ', '8', '2', '2018']
# ['Call Blocker', 'BUSINESS', '4.6', '188841', '3200.0', '5000000', 'Free', '0.0', 'Everyone', 'Business', '2018-06-21', '1.1.13', '4.0 ', '21', '6', '2018']
# ['Plugin:AOT v5.0', 'BUSINESS', '3.1', '4034', '23.0', '100000', 'Free', '0.0', 'Everyone', 'Business', '2015-09-11', '3.0.1.11 (Build 311)', '2.2 ', '11', '9', '2015']
# ['Kariyer.net', 'BUSINESS', '3.9', '45964', '16000.0', '1000000', 'Free', '0.0', 'Everyone', 'Business', '2018-07-18', '5.1.5', '4.1 ', '18', '7', '2018']
# ['Become a Job - Find a job or advertise', 'BUSINESS', '4.1', '6903', '14000.0', '1000000', 'Free', '0.0', 'Everyone', 'Business', '2018-07-10', '2.3.6', '4.1 ', '10', '7', '2018']
# ['ZOOM Cloud Meetings', 'BUSINESS', '4.4', '31614', '37000.0', '10000000', 'Free', '0.0', 'Everyone', 'Business', '2018-07-20', '4.1.28165.0716', '4.0 ', '20', '7', '2018']
# ['IndiaMART: Search Products, Buy, Sell & Trade', 'BUSINESS', '4.5', '207372', '11000.0', '5000000', 'Free', '0.0', 'Everyone', 'Business', '2018-08-02', '12.2.4', '4.0 ', '2', '8', '2018']
# ['ViettelPost express delivery', 'BUSINESS', '4.4', '1225', '25000.0', '100000', 'Free', '0.0', 'Everyone', 'Business', '2018-08-01', '1.0.6.8', '4.1 ', '1', '8', '2018']
# ['MyASUS - Service Center', 'BUSINESS', '4.4', '380837', '7300.0', '10000000', 'Free', '0.0', 'Everyone', 'Business', '2018-07-04', '3.4.5', '4.2 ', '4', '7', '2018']
# ['Job Korea - Career Jobs', 'BUSINESS', '4.3', '10600', '6500.0', '1000000', 'Free', '0.0', 'Everyone', 'Business', '2018-08-01', '2.5.6', '4.0 ', '1', '8', '2018']
# ['104 Looking for a job - looking for a job, looking for a job, looking for a part-time job, health checkup, resume, treatment room', 'BUSINESS', '4.4', '74359', '25000.0', '1000000', 'Free', '0.0', 'Everyone', 'Business', '2018-07-27', '1.12.5', '4.0 ', '27', '7', '2018']
# ['Myanmar 2D/3D', 'BUSINESS', '4.6', '822', '3100.0', '100000', 'Free', '0.0', 'Everyone', 'Business', '2018-06-08', '1.5', '4.0.3 ', '8', '6', '2018']
# ['sABN', 'BUSINESS', '4.4', '2287', '1500.0', '1000000', 'Free', '0.0', 'Everyone', 'Business', '2018-03-26', '4.9', '2.2 ', '26', '3', '2018']
# ['ATI Cargoes and Transportation', 'BUSINESS', '4.7', '4162', '7500.0', '100000', 'Free', '0.0', 'Everyone', 'Business', '2018-07-24', '0.9.4', '4.0.3 ', '24', '7', '2018']
# ['Secure Folder', 'BUSINESS', '3.8', '14760', '8600.0', '50000000', 'Free', '0.0', 'Everyone', 'Business', '2018-01-31', '1.1.07.6', '7.0 ', '31', '1', '2018']
# ['Tiny Scanner - PDF Scanner App', 'BUSINESS', '4.7', '286897', '39000.0', '10000000', 'Free', '0.0', 'Everyone', 'Business', '2017-05-30', '1.2.6', '3.0 ', '30', '5', '2017']
# ['Fast Scanner : Free PDF Scan', 'BUSINESS', '4.5', '103755', '14000.0', '10000000', 'Free', '0.0', 'Everyone', 'Business', '2018-07-11', '3.9.2', '4.1 ', '11', '7', '2018']
# ['Mobile Doc Scanner (MDScan) Lite', 'BUSINESS', '4.2', '46505', '19000.0', '1000000', 'Free', '0.0', 'Everyone', 'Business', '2018-08-02', '3.4.49', '4.1 ', '2', '8', '2018']
# ['TurboScan: scan documents and receipts in PDF', 'BUSINESS', '4.7', '11442', '6800.0', '100000', 'Paid', '4.99', 'Everyone', 'Business', '2018-03-25', '1.5.2', '4.0 ', '25', '3', '2018']
# ['Tiny Scanner Pro: PDF Doc Scan', 'BUSINESS', '4.8', '10295', '39000.0', '100000', 'Paid', '4.99', 'Everyone', 'Business', '2017-04-11', '3.4.6', '3.0 ', '11', '4', '2017']
# ['Zenefits', 'BUSINESS', '4.2', '296', '14000.0', '50000', 'Free', '0.0', 'Everyone', 'Business', '2018-06-15', '3.2.1', '4.1 ', '15', '6', '2018']
# ['Google Ads', 'BUSINESS', '4.3', '29313', '20000.0', '5000000', 'Free', '0.0', 'Everyone', 'Business', '2018-07-30', '1.12.0', '4.0.3 ', '30', '7', '2018']
# ['FreshBooks Classic', 'BUSINESS', '4.1', '1802', '26000.0', '100000', 'Free', '0.0', 'Everyone', 'Business', '2018-04-18', '1.7.14', '4.2 ', '18', '4', '2018']
# ['Insightly CRM', 'BUSINESS', '3.8', '1383', '51000.0', '100000', 'Free', '0.0', 'Everyone', 'Business', '2018-07-12', '3.24.1', '5.0 ', '12', '7', '2018']
# ['QuickBooks Accounting: Invoicing & Expenses', 'BUSINESS', '4.3', '23175', '41000.0', '1000000', 'Free', '0.0', 'Everyone', 'Business', '2018-07-13', '18.7', '4.1 ', '13', '7', '2018']
# ['HipChat - Chat Built for Teams', 'BUSINESS', '3.8', '5868', '20000.0', '500000', 'Free', '0.0', 'Everyone', 'Business', '2018-07-03', '3.19.005', '4.1 ', '3', '7', '2018']
# ['MailChimp - Email, Marketing Automation', 'BUSINESS', '4.1', '5448', '12000.0', '500000', 'Free', '0.0', 'Everyone', 'Business', '2018-07-25', '4.9.1', '5.0 ', '25', '7', '2018']
# ['Crew - Free Messaging and Scheduling', 'BUSINESS', '4.6', '4159', '48000.0', '500000', 'Free', '0.0', 'Everyone', 'Business', '2018-07-20', '6.1.2', '4.0.3 ', '20', '7', '2018']
# ['Asana: organize team projects', 'BUSINESS', '4.3', '20815', '10000.0', '1000000', 'Free', '0.0', 'Everyone', 'Business', '2018-07-26', '6.4.4', '5.0 ', '26', '7', '2018']
# ['Google Analytics', 'BUSINESS', '4.5', '78662', '22000.0', '1000000', 'Free', '0.0', 'Everyone', 'Business', '2018-02-13', '3.7.5', '4.4 ', '13', '2', '2018']
# ['AdWords Express', 'BUSINESS', '4.1', '7149', '11000.0', '1000000', 'Free', '0.0', 'Everyone', 'Business', '2018-07-31', '2.6.158', '4.0 ', '31', '7', '2018']
# ['Accounting App - Zoho Books', 'BUSINESS', '4.5', '3079', '8500.0', '100000', 'Free', '0.0', 'Everyone', 'Business', '2018-08-02', '5.20.7', '4.1 ', '2', '8', '2018']
# ['Invoice & Time Tracking - Zoho', 'BUSINESS', '4.6', '5800', '8600.0', '100000', 'Free', '0.0', 'Everyone', 'Business', '2018-08-02', '5.20.7', '4.1 ', '2', '8', '2018']
# ['Invoice 2go â€” Professional Invoices and Estimates', 'BUSINESS', '4.2', '16422', '28000.0', '1000000', 'Free', '0.0', 'Everyone', 'Business', '2018-08-01', '10.46.2', '4.1 ', '1', '8', '2018']
# ['Cisco Webex Meetings', 'BUSINESS', '4.4', '108741', '28000.0', '10000000', 'Free', '0.0', 'Everyone', 'Business', '2018-07-20', '11.1.0', '4.3 ', '20', '7', '2018']
# ['ScreenMeet. Easy Phone Meeting', 'BUSINESS', '4.0', '624', '9000.0', '100000', 'Free', '0.0', 'Everyone', 'Business', '2018-03-22', '1.2.287', '5.0 ', '22', '3', '2018']
# ['Cisco Webex Teams', 'BUSINESS', '4.2', '1661', '46000.0', '100000', 'Free', '0.0', 'Everyone', 'Business', '2018-08-02', '3.0.4651', '4.4 ', '2', '8', '2018']
# ['Start Meeting', 'BUSINESS', '4.1', '308', '14000.0', '50000', 'Free', '0.0', 'Everyone', 'Business', '2018-05-29', '3.1.4.0', '4.0.3 ', '29', '5', '2018']
# ['ClickMeeting Webinars', 'BUSINESS', '3.8', '5211', '26000.0', '1000000', 'Free', '0.0', 'Everyone', 'Business', '2018-07-30', '3.3.0', '4.0 ', '30', '7', '2018']
# ['BlueJeans for Android', 'BUSINESS', '3.9', '1058', '23000.0', '500000', 'Free', '0.0', 'Everyone', 'Business', '2018-06-29', '2.22.397', '5.0 ', '29', '6', '2018']
# ['OfficeSuite : Free Office + PDF Editor', 'BUSINESS', '4.3', '1002859', '35000.0', '100000000', 'Free', '0.0', 'Everyone', 'Business', '2018-08-02', '9.7.14188', '4.1 ', '2', '8', '2018']
# ['Verify - Receipts & Expenses', 'BUSINESS', '4.5', '413', '29000.0', '10000', 'Free', '0.0', 'Everyone', 'Business', '2018-07-25', '2.0.19', '5.0 ', '25', '7', '2018']
# ['Manga Master - Best manga & comic reader', 'COMICS', '4.6', '24005', '4900.0', '500000', 'Free', '0.0', 'Adults only 18+', 'Comics', '2018-07-04', '1.1.7.0', '4.1 ', '4', '7', '2018']
# ['GANMA! - All original stories free of charge for all original comics', 'COMICS', '4.7', '57106', '27000.0', '1000000', 'Free', '0.0', 'Teen', 'Comics', '2018-07-23', '2.11.3', '4.1 ', '23', '7', '2018']
# ['RÃ¶hrich Werner Soundboard', 'COMICS', '4.7', '2249', '32000.0', '500000', 'Free', '0.0', 'Everyone', 'Comics', '2017-11-16', '1.08', '4.0.3 ', '16', '11', '2017']
# ['Unicorn Pokez - Color By Number', 'COMICS', '4.8', '516', '12000.0', '50000', 'Free', '0.0', 'Everyone', 'Comics;Creativity', '2018-08-03', '1.0.6', '4.4 ', '3', '8', '2018']
# ['MangaToon - Comics updated Daily', 'COMICS', '3.9', '834', '15000.0', '50000', 'Free', '0.0', 'Mature 17+', 'Comics', '2018-08-01', '1.0.8', '4.1 ', '1', '8', '2018']
# ['Manga Net â€“ Best Online Manga Reader', 'COMICS', '4.1', '1010', '11000.0', '50000', 'Free', '0.0', 'Mature 17+', 'Comics', '2018-07-07', '1.5', '4.1 ', '7', '7', '2018']
# ['Manga Rock - Best Manga Reader', 'COMICS', '4.4', '238970', '28000.0', '1000000', 'Free', '0.0', 'Teen', 'Comics', '2018-07-09', '3.4.3_world', '5.0 ', '9', '7', '2018']
# ['Manga - read Thai translation', 'COMICS', '4.6', '302', '2200.0', '10000', 'Free', '0.0', 'Teen', 'Comics', '2018-07-03', '1.0', '4.0 ', '3', '7', '2018']
# ['The Vietnam Story - Fun Stories', 'COMICS', '4.5', '438', '3400.0', '10000', 'Free', '0.0', 'Everyone', 'Comics', '2017-12-27', '1.0', '2.3 ', '27', '12', '2017']
# ['Dragon Ball Wallpaper - Ringtones', 'COMICS', '4.7', '73', '8300.0', '10000', 'Free', '0.0', 'Everyone', 'Comics', '2018-07-23', '1.9', '4.0.3 ', '23', '7', '2018']
# ['Funny Jokes Photos', 'COMICS', '4.4', '39', '4300.0', '10000', 'Free', '0.0', 'Everyone 10+', 'Comics', '2018-07-03', '1.1', '4.2 ', '3', '7', '2018']
# ['Truyá»‡n Vui TÃ½ Quáº\xady', 'COMICS', '4.5', '144', '4700.0', '10000', 'Free', '0.0', 'Everyone', 'Comics', '2018-07-19', '3.0', '4.0.3 ', '19', '7', '2018']
# ['Comic Es - Shojo manga / love comics free of charge â™ª â™ª', 'COMICS', '3.9', '2181', '10000.0', '100000', 'Free', '0.0', 'Teen', 'Comics', '2018-03-05', '1.2.12', '4.0.3 ', '5', '3', '2018']
# ['comico Popular Original Cartoon Updated Everyday Comico', 'COMICS', '3.2', '93965', '15000.0', '5000000', 'Free', '0.0', 'Teen', 'Comics', '2018-07-03', '6.3.0', '4.0.3 ', '3', '7', '2018']
# ['Daily Manga - Comic & Webtoon', 'COMICS', '3.2', '1446', '7100.0', '100000', 'Free', '0.0', 'Mature 17+', 'Comics', '2018-05-18', '1.0', '4.0.3 ', '18', '5', '2018']
# ['æ¼«å’– Comics - Manga,Novel and Stories', 'COMICS', '4.1', '12088', '21000.0', '1000000', 'Free', '0.0', 'Mature 17+', 'Comics', '2018-07-06', '2.3.1', '4.0.3 ', '6', '7', '2018']
# ['Emmanuella Funny Videos 2018', 'COMICS', '4.5', '314', '6100.0', '100000', 'Free', '0.0', 'Everyone', 'Comics', '2018-05-23', '3.1.0', '4.1 ', '23', '5', '2018']
# ['Manga Zero - Japanese cartoon and comic reader', 'COMICS', '4.2', '15194', '15000.0', '1000000', 'Free', '0.0', 'Teen', 'Comics', '2018-07-19', '4.7.3', '4.2 ', '19', '7', '2018']
# ['Marvel Unlimited', 'COMICS', '3.7', '22551', '11000.0', '1000000', 'Free', '0.0', 'Teen', 'Comics', '2018-07-24', '3.16.0', '4.4 ', '24', '7', '2018']
# ['Tapas â€“ Comics, Novels, and Stories', 'COMICS', '4.5', '29839', '29000.0', '1000000', 'Free', '0.0', 'Teen', 'Comics', '2018-07-31', '4.1.0', '4.4 ', '31', '7', '2018']
# ["Children's cartoons (Mithu-Mina-Raju)", 'COMICS', '4.6', '279', '3300.0', '100000', 'Free', '0.0', 'Everyone', 'Comics', '2017-12-18', '1.6', '4.0 ', '18', '12', '2017']
# ['Faustop Sounds', 'COMICS', '4.7', '1677', '40000.0', '100000', 'Free', '0.0', 'Everyone', 'Comics', '2018-05-26', '1.7.7', '4.1 ', '26', '5', '2018']
# ['Manga Mania - Best online manga reader', 'COMICS', '4.4', '757', '10000.0', '10000', 'Free', '0.0', 'Teen', 'Comics', '2018-05-24', '1.0', '4.1 ', '24', '5', '2018']
# ['- Free Comics - Comic Apps', 'COMICS', '3.5', '115', '9100.0', '10000', 'Free', '0.0', 'Mature 17+', 'Comics', '2018-07-13', '5.0.12', '5.0 ', '13', '7', '2018']
# ['Manga AZ - Manga Comic Reader', 'COMICS', '3.3', '125', '4700.0', '5000', 'Free', '0.0', 'Teen', 'Comics', '2018-07-24', '1.0.4', '4.0.3 ', '24', '7', '2018']
# ['Buff Thun - Daily Free Webtoon / Comics / Web Fiction / Mini Game', 'COMICS', '4.5', '9952', '38000.0', '500000', 'Free', '0.0', 'Everyone 10+', 'Comics', '2018-07-31', '4.3.0', '4.1 ', '31', '7', '2018']
# ['Funny Jokes and Stories 2018', 'COMICS', '4.2', '21', '6700.0', '5000', 'Free', '0.0', 'Everyone', 'Comics', '2018-03-31', '1.3', '4.0 ', '31', '3', '2018']
# ['Hojiboy Tojiboyev Life Hacks', 'COMICS', '5.0', '15', '37000.0', '1000', 'Free', '0.0', 'Everyone', 'Comics', '2018-06-26', '2.0', '4.0.3 ', '26', '6', '2018']
# ['Best Wallpapers Backgrounds(100,000+ 4K HD)', 'COMICS', '4.7', '3596', '7800.0', '10000', 'Free', '0.0', 'Teen', 'Comics', '2018-06-16', '1.01', '4.0.3 ', '16', '6', '2018']
# ['think Comics', 'COMICS', '4.4', '1006', '19000.0', '50000', 'Free', '0.0', 'Everyone', 'Comics', '2018-08-03', '2.3.3', '4.0.3 ', '3', '8', '2018']
# ['Memes Button', 'COMICS', '4.4', '5968', '5700.0', '1000000', 'Free', '0.0', 'Everyone', 'Comics', '2018-05-28', '1.4', '4.0 ', '28', '5', '2018']
# ['Laftel - Watching and Announcing Snooping, Streaming', 'COMICS', '4.6', '4895', '35000.0', '100000', 'Free', '0.0', 'Everyone', 'Comics', '2018-08-02', '2.4.25', '4.4 ', '2', '8', '2018']
# ['Messenger for SMS', 'COMMUNICATION', '4.3', '125257', '17000.0', '10000000', 'Free', '0.0', 'Teen', 'Communication', '2018-06-06', '1.8.9', '4.1 ', '6', '6', '2018']
# ['My Tele2', 'COMMUNICATION', '4.3', '158679', '8800.0', '5000000', 'Free', '0.0', 'Everyone', 'Communication', '2018-08-03', '2.4.1', '4.4 ', '3', '8', '2018']
# ['Yahoo Mail â€“ Stay Organized', 'COMMUNICATION', '4.3', '4187998', '16000.0', '100000000', 'Free', '0.0', 'Everyone', 'Communication', '2018-07-18', '5.29.3', '4.4 ', '18', '7', '2018']
# ['imo beta free calls and text', 'COMMUNICATION', '4.3', '659395', '11000.0', '100000000', 'Free', '0.0', 'Everyone', 'Communication', '2018-06-07', '9.8.000000010492', '4.0 ', '7', '6', '2018']
# ['imo free video calls and chat', 'COMMUNICATION', '4.3', '4785892', '11000.0', '500000000', 'Free', '0.0', 'Everyone', 'Communication', '2018-06-08', '9.8.000000010501', '4.0 ', '8', '6', '2018']
# ['Call Free â€“ Free Call', 'COMMUNICATION', '4.3', '30209', '15000.0', '5000000', 'Free', '0.0', 'Everyone', 'Communication', '2018-07-28', '1.3.4', '4.1 ', '28', '7', '2018']
# ['Web Browser & Explorer', 'COMMUNICATION', '4.0', '36901', '6600.0', '5000000', 'Free', '0.0', 'Everyone', 'Communication', '2018-07-04', '11.8.6', '4.0.3 - 7.1.1', '4', '7', '2018']
# ['Browser 4G', 'COMMUNICATION', '4.3', '192948', '6600.0', '10000000', 'Free', '0.0', 'Everyone', 'Communication', '2018-06-19', '24.6.6', '4.0.3 - 7.1.1', '19', '6', '2018']
# ['Cricket Visual Voicemail', 'COMMUNICATION', '3.9', '13698', '5100.0', '10000000', 'Free', '0.0', 'Everyone', 'Communication', '2018-07-02', '3.2.0.100171', '4.1 ', '2', '7', '2018']
# ['TracFone My Account', 'COMMUNICATION', '3.6', '20769', '18000.0', '1000000', 'Free', '0.0', 'Everyone', 'Communication', '2018-07-11', 'R6.0.3', '4.1 ', '11', '7', '2018']
# ['Firefox Focus: The privacy browser', 'COMMUNICATION', '4.4', '36880', '4000.0', '1000000', 'Free', '0.0', 'Everyone', 'Communication', '2018-07-06', '5.2', '5.0 ', '6', '7', '2018']
# ['TouchPal Keyboard - Fun Emoji & Android Keyboard', 'COMMUNICATION', '4.4', '615381', '37000.0', '10000000', 'Free', '0.0', 'Mature 17+', 'Communication', '2018-08-02', '6.7.9.1', '4.0.3 ', '2', '8', '2018']
# ['Skype Lite - Free Video Call & Chat', 'COMMUNICATION', '4.2', '33053', '22000.0', '5000000', 'Free', '0.0', 'Everyone', 'Communication', '2018-07-31', '1.60.0.31354-release', '4.0.3 ', '31', '7', '2018']
# ['UC Browser Mini -Tiny Fast Private & Secure', 'COMMUNICATION', '4.4', '3648120', '3300.0', '100000000', 'Free', '0.0', 'Teen', 'Communication', '2018-07-18', '11.4.0', '4.0 ', '18', '7', '2018']
# ['WhatsApp Business', 'COMMUNICATION', '4.4', '136662', '32000.0', '10000000', 'Free', '0.0', 'Everyone', 'Communication', '2018-07-30', '2.18.116', '4.0.3 ', '30', '7', '2018']
# ['My magenta', 'COMMUNICATION', '3.9', '42370', '37000.0', '1000000', 'Free', '0.0', 'Everyone', 'Communication', '2018-06-25', '7.5.1', '5.0 ', '25', '6', '2018']
# ['Antillean Gold Telegram (original version)', 'COMMUNICATION', '4.4', '2939', '17000.0', '100000', 'Free', '0.0', 'Everyone', 'Communication', '2018-07-16', '2.1', '4.1 ', '16', '7', '2018']
# ['Omlet Chat', 'COMMUNICATION', '3.9', '40751', '35000.0', '10000000', 'Free', '0.0', 'Teen', 'Communication', '2016-11-04', '2.2.7600', '4.0.3 ', '4', '11', '2016']
# ['UC Browser - Fast Download Private & Secure', 'COMMUNICATION', '4.5', '17712922', '40000.0', '500000000', 'Free', '0.0', 'Teen', 'Communication', '2018-08-02', '12.8.5.1121', '4.0 ', '2', '8', '2018']
# ['My Vodacom SA', 'COMMUNICATION', '3.7', '25021', '61000.0', '5000000', 'Free', '0.0', 'Everyone', 'Communication', '2018-06-26', '9.9.0', '4.3 ', '26', '6', '2018']
# ['Microsoft Edge', 'COMMUNICATION', '4.3', '27187', '66000.0', '5000000', 'Free', '0.0', 'Everyone', 'Communication', '2018-07-28', '42.0.0.2059', '4.4 ', '28', '7', '2018']
# ['imo free video calls and chat', 'COMMUNICATION', '4.3', '4785988', '11000.0', '500000000', 'Free', '0.0', 'Everyone', 'Communication', '2018-06-08', '9.8.000000010501', '4.0 ', '8', '6', '2018']
# ['Hangouts Dialer - Call Phones', 'COMMUNICATION', '4.0', '122498', '79.0', '10000000', 'Free', '0.0', 'Everyone', 'Communication', '2015-09-02', '0.1.100944346', '4.0.3 ', '2', '9', '2015']
# ['Talkatone: Free Texts, Calls & Phone Number', 'COMMUNICATION', '4.1', '132014', '25000.0', '10000000', 'Free', '0.0', 'Everyone', 'Communication', '2018-07-18', '6.1', '4.2 ', '18', '7', '2018']
# ['Calls & Text by Mo+', 'COMMUNICATION', '4.2', '83239', '14000.0', '5000000', 'Free', '0.0', 'Everyone', 'Communication', '2018-04-19', '3.0.4', '4.0 ', '19', '4', '2018']
# ['GO SMS Pro - Messenger, Free Themes, Emoji', 'COMMUNICATION', '4.4', '2876500', '24000.0', '100000000', 'Free', '0.0', 'Everyone', 'Communication', '2018-08-01', '7.73', '4.0 ', '1', '8', '2018']
# ['Messaging+ SMS, MMS Free', 'COMMUNICATION', '4.1', '28238', '17000.0', '1000000', 'Free', '0.0', 'Everyone', 'Communication', '2018-08-02', '4.98', '2.3 ', '2', '8', '2018']
# ['chomp SMS', 'COMMUNICATION', '4.3', '335646', '8300.0', '10000000', 'Free', '0.0', 'Everyone', 'Communication', '2018-07-26', '7.21', '2.3 ', '26', '7', '2018']
# ['Text SMS', 'COMMUNICATION', '4.5', '349384', '8200.0', '10000000', 'Free', '0.0', 'Everyone', 'Communication', '2018-07-24', '3.47', '4.0.3 ', '24', '7', '2018']
# ['mysms SMS Text Messaging Sync', 'COMMUNICATION', '4.3', '37320', '8400.0', '1000000', 'Free', '0.0', 'Everyone', 'Communication', '2018-07-30', '6.5.1', '4.0.3 ', '30', '7', '2018']
# ['Firefox Focus: The privacy browser', 'COMMUNICATION', '4.4', '36893', '4000.0', '1000000', 'Free', '0.0', 'Everyone', 'Communication', '2018-07-06', '5.2', '5.0 ', '6', '7', '2018']
# ['2ndLine - Second Phone Number', 'COMMUNICATION', '4.2', '15880', '32000.0', '1000000', 'Free', '0.0', 'Everyone', 'Communication', '2018-08-03', '5.65.0', '4.0 ', '3', '8', '2018']
# ['CM Browser - Ad Blocker , Fast Download , Privacy', 'COMMUNICATION', '4.6', '2264916', '6100.0', '50000000', 'Free', '0.0', 'Everyone', 'Communication', '2018-07-31', '5.22.18.0006', '4.0 ', '31', '7', '2018']
# ['Ninesky Browser', 'COMMUNICATION', '4.2', '42925', '2800.0', '1000000', 'Free', '0.0', 'Everyone', 'Communication', '2017-08-27', '6.1', '2.3 ', '27', '8', '2017']
# ['UC Browser Mini -Tiny Fast Private & Secure', 'COMMUNICATION', '4.4', '3648480', '3300.0', '100000000', 'Free', '0.0', 'Teen', 'Communication', '2018-07-18', '11.4.0', '4.0 ', '18', '7', '2018']
# ['UC Browser - Fast Download Private & Secure', 'COMMUNICATION', '4.5', '17714850', '40000.0', '500000000', 'Free', '0.0', 'Teen', 'Communication', '2018-08-02', '12.8.5.1121', '4.0 ', '2', '8', '2018']
# ...
# ['2Date Dating App, Love and matching', 'DATING', '4.4', '41605', '8100.0', '500000', 'Free', '0.0', 'Mature 17+', 'Dating', '2018-07-26', '4.813', '4.0.3 ', '26', '7', '2018']
# ['FlirtChat - â™¥Free Dating/Flirting Appâ™¥', 'DATING', '4.3', '2433', '13000.0', '500000', 'Free', '0.0', 'Mature 17+', 'Dating', '2018-07-26', '12.0.4', '4.1 ', '26', '7', '2018']
# ['Teenage Chat & Dating', 'DATING', '3.4', '5', '14000.0', '500', 'Free', '0.0', 'Mature 17+', 'Dating', '2018-07-09', '1.2', '4.1 ', '9', '7', '2018']
# ['Girls Online Talk - Free Text and Video Chat', 'DATING', '4.7', '791', '3700.0', '10000', 'Free', '0.0', 'Mature 17+', 'Dating', '2018-05-15', '8.2', '4.0.3 ', '15', '5', '2018']
# ['Online Girls Chat', 'DATING', '4.8', '5323', '3500.0', '50000', 'Free', '0.0', 'Mature 17+', 'Dating', '2018-04-21', '8.2', '4.0.3 ', '21', '4', '2018']
# ['LIVE VIDEO TALK', 'DATING', '4.7', '478', '4500.0', '10000', 'Free', '0.0', 'Mature 17+', 'Dating', '2018-06-28', '8.2', '4.0.3 ', '28', '6', '2018']
# ['SkyLove â€“ Dating and chat', 'DATING', '3.5', '69', '36000.0', '5000', 'Free', '0.0', 'Mature 17+', 'Dating', '2018-08-04', '1.0.82', '4.4 ', '4', '8', '2018']
# ['Free Live Talk-Video Call', 'DATING', '4.7', '158', '4500.0', '10000', 'Free', '0.0', 'Mature 17+', 'Dating', '2018-07-05', '8.2', '4.0.3 ', '5', '7', '2018']
# ['FindLoving', 'DATING', '3.8', '24', '19000.0', '1000', 'Free', '0.0', 'Mature 17+', 'Dating', '2018-08-02', '1.0.5', '4.0 ', '2', '8', '2018']
# ['Sugar Daddies Dating App', 'DATING', '2.9', '53', '14000.0', '10000', 'Free', '0.0', 'Mature 17+', 'Dating', '2018-07-10', '4.1', '4.1 ', '10', '7', '2018']
# ['Free Dating App - YoCutie - Flirt, Chat & Meet', 'DATING', '4.1', '97699', '7900.0', '1000000', 'Free', '0.0', 'Mature 17+', 'Dating', '2018-07-10', '1.230', '4.0.3 ', '10', '7', '2018']
# ['TED', 'EDUCATION', '4.6', '181893', '18000.0', '10000000', 'Free', '0.0', 'Everyone 10+', 'Education', '2018-07-27', '3.2.5', '4.1 ', '27', '7', '2018']
# ['English Communication - Learn English for Chinese (Learn English for Chinese)', 'EDUCATION', '4.7', '2544', '18000.0', '100000', 'Free', '0.0', 'Everyone', 'Education', '2017-12-29', '3.1', '4.0 ', '29', '12', '2017']
# ['Khan Academy', 'EDUCATION', '4.6', '85375', '21000.0', '5000000', 'Free', '0.0', 'Everyone', 'Education', '2018-07-27', '5.0.0', '4.1 ', '27', '7', '2018']
# ['Learn English with Wlingua', 'EDUCATION', '4.7', '314299', '3300.0', '10000000', 'Free', '0.0', 'Everyone', 'Education', '2018-05-02', '1.94.9', '4.0 ', '2', '5', '2018']
# ['Princess Coloring Book', 'EDUCATION', '4.5', '9770', '39000.0', '5000000', 'Free', '0.0', 'Everyone', 'Education;Creativity', '2018-02-25', '1.2.8', '4.0 ', '25', '2', '2018']
# ['Learn Spanish - EspaÃ±ol', 'EDUCATION', '4.7', '32346', '3200.0', '1000000', 'Free', '0.0', 'Everyone', 'Education', '2017-12-18', '1.3.8', '4.0 ', '18', '12', '2017']
# ['English Grammar Test', 'EDUCATION', '4.8', '4075', '5100.0', '500000', 'Free', '0.0', 'Everyone', 'Education', '2018-06-22', '2.1.8', '4.0.3 ', '22', '6', '2018']
# ['Speed Reading', 'EDUCATION', '4.6', '10611', '11000.0', '500000', 'Free', '0.0', 'Everyone', 'Education', '2018-05-27', '2.3.7', '4.0 ', '27', '5', '2018']
# ['English for beginners', 'EDUCATION', '4.6', '9321', '27000.0', '1000000', 'Free', '0.0', 'Everyone', 'Education', '2018-07-18', '2.9.0', '4.0 ', '18', '7', '2018']
# ['Flame - Ø¯Ø±Ø¨ Ø¹Ù‚Ù„Ùƒ ÙŠÙˆÙ…ÙŠØ§', 'EDUCATION', '4.6', '56065', '37000.0', '1000000', 'Free', '0.0', 'Everyone', 'Education', '2018-07-26', '3.3', '4.1 ', '26', '7', '2018']
# ['Learn Japanese, Korean, Chinese Offline & Free', 'EDUCATION', '4.9', '133136', '26000.0', '1000000', 'Free', '0.0', 'Everyone', 'Education;Education', '2018-07-20', '2.16.11.10', '4.2 ', '20', '7', '2018']
# ['Kids Mode', 'EDUCATION', '3.8', '2469', '11000.0', '500000', 'Free', '0.0', 'Everyone', 'Education', '2018-03-23', 'Varies with device', 'nan', '23', '3', '2018']
# ['Dinosaurs Coloring Pages', 'EDUCATION', '4.4', '390', '41000.0', '500000', 'Free', '0.0', 'Everyone', 'Education;Education', '2018-02-03', '1.1.6', '4.0 ', '3', '2', '2018']
# ['Cars Coloring Pages', 'EDUCATION', '4.4', '1090', '49000.0', '1000000', 'Free', '0.0', 'Everyone', 'Education;Creativity', '2018-02-03', '1.2.0', '4.0 ', '3', '2', '2018']
# ['Babbel â€“ Learn Languages', 'EDUCATION', '4.3', '266948', '21000.0', '10000000', 'Free', '0.0', 'Everyone', 'Education', '2018-07-30', '20.7.2', '4.4 ', '30', '7', '2018']
# ['Math Tricks', 'EDUCATION', '4.5', '342918', '8100.0', '10000000', 'Free', '0.0', 'Everyone', 'Education', '2018-07-29', '2.24', '4.0 ', '29', '7', '2018']
# ['Monster Truck Driver & Racing', 'EDUCATION', '4.4', '748', '51000.0', '1000000', 'Free', '0.0', 'Everyone', 'Education;Action & Adventure', '2017-01-19', '1.0.9', '2.3 ', '19', '1', '2017']
# ['Learn English Words Free', 'EDUCATION', '4.6', '172640', '14000.0', '5000000', 'Free', '0.0', 'Everyone', 'Education', '2018-05-02', '2.6.2', '4.1 ', '2', '5', '2018']
# ['Japanese / English one-shop search dictionary - Free Japanese - English - Japanese dictionary application', 'EDUCATION', '3.9', '61', '18000.0', '50000', 'Free', '0.0', 'Mature 17+', 'Education', '2018-05-28', '1.4.2', '5.0 ', '28', '5', '2018']
# ['English speaking texts', 'EDUCATION', '4.4', '1619', '3000.0', '1000000', 'Free', '0.0', 'Everyone', 'Education', '2018-07-20', '1.2', '1.6 ', '20', '7', '2018']
# ['Thai Handwriting', 'EDUCATION', '4.3', '3168', '19000.0', '1000000', 'Free', '0.0', 'Everyone', 'Education', '2017-10-26', '3.1', '4.4 ', '26', '10', '2017']
# ['Kanji test Â· Han search Kanji training (free version)', 'EDUCATION', '4.2', '6736', '22000.0', '1000000', 'Free', '0.0', 'Mature 17+', 'Education', '2017-10-17', '2.51.0', '4.0.3 ', '17', '10', '2017']
# ["Game for KIDS: KIDS match'em", 'EDUCATION', '4.4', '7005', '6900.0', '1000000', 'Free', '0.0', 'Everyone', 'Education', '2016-10-23', '1.17', '2.3 ', '23', '10', '2016']
# ['Flippy Campus - Buy & sell on campus at a discount', 'EDUCATION', '4.0', '889', '7400.0', '500000', 'Free', '0.0', 'Everyone', 'Education', '2018-03-09', '2.2.4', '4.2 ', '9', '3', '2018']
# ['Free intellectual training game application |', 'EDUCATION', '4.2', '5741', '84000.0', '1000000', 'Free', '0.0', 'Everyone', 'Education;Pretend Play', '2018-07-25', '3.7.0', '4.4 ', '25', '7', '2018']
# ['ABC Preschool Free', 'EDUCATION', '3.8', '27572', '25000.0', '5000000', 'Free', '0.0', 'Everyone', 'Education;Education', '2017-10-25', '3.0', '2.3 ', '25', '10', '2017']
# ['PINKFONG Baby Shark', 'EDUCATION', '4.5', '10852', '18000.0', '1000000', 'Free', '0.0', 'Everyone', 'Education', '2017-11-28', '10', '4.1 ', '28', '11', '2017']
# ['Learn English for beginners', 'EDUCATION', '4.5', '1929', '2500.0', '500000', 'Free', '0.0', 'Everyone', 'Education', '2017-09-28', '1.1', '2.3 ', '28', '9', '2017']
# ['Listen and learn English in seven days', 'EDUCATION', '4.3', '1516', '3900.0', '100000', 'Free', '0.0', 'Everyone', 'Education', '2018-07-28', '3.1', '4.1 ', '28', '7', '2018']
# ['Learn English from Persian: Persian to English', 'EDUCATION', '4.3', '423', '21000.0', '100000', 'Free', '0.0', 'Everyone', 'Education', '2018-04-03', '6.0', '4.0.3 ', '3', '4', '2018']
# ['English with Lingualeo', 'EDUCATION', '4.7', '254519', '27000.0', '5000000', 'Free', '0.0', 'Everyone', 'Education', '2018-07-20', '2.8.1', '4.1 ', '20', '7', '2018']
# ['Udemy - Online Courses', 'EDUCATION', '4.5', '99020', '18000.0', '1000000', 'Free', '0.0', 'Everyone', 'Education', '2018-08-02', '5.0.4', '5.0 ', '2', '8', '2018']
# ['edX - Online Courses by Harvard, MIT & more', 'EDUCATION', '4.6', '32381', '10000.0', '1000000', 'Free', '0.0', 'Everyone 10+', 'Education', '2018-07-15', '2.15.1', '4.1 ', '15', '7', '2018']
# ['Memorado - Brain Games', 'EDUCATION', '4.4', '56897', '97000.0', '1000000', 'Free', '0.0', 'Everyone', 'Education;Brain Games', '2017-01-16', '1.10.0', '4.1 ', '16', '1', '2017']
# ['Lynda - Online Training Videos', 'EDUCATION', '4.2', '8599', '17000.0', '1000000', 'Free', '0.0', 'Everyone', 'Education', '2018-07-11', '4.9.10', '4.1 ', '11', '7', '2018']
# ['Quiz&Learn Python', 'EDUCATION', '4.0', '304', '2000.0', '10000', 'Free', '0.0', 'Everyone', 'Education', '2016-07-04', '1.3.0', '4.0 ', '4', '7', '2016']
# ['C++ Tutorials', 'EDUCATION', '4.1', '358', '1900.0', '50000', 'Free', '0.0', 'Everyone', 'Education', '2014-08-21', '1.1', '2.3 ', '21', '8', '2014']
# ['C++ Programming', 'EDUCATION', '4.3', '11904', '1800.0', '1000000', 'Free', '0.0', 'Everyone', 'Education', '2015-08-22', '2.0', '2.3 ', '22', '8', '2015']
# ['C Programming', 'EDUCATION', '4.3', '22251', '1800.0', '1000000', 'Free', '0.0', 'Everyone', 'Education', '2015-06-28', '3.0', '2.3 ', '28', '6', '2015']
# ['Udacity - Lifelong Learning', 'EDUCATION', '4.3', '22384', '17000.0', '1000000', 'Free', '0.0', 'Everyone', 'Education', '2018-07-31', '4.7.0', '5.0 ', '31', '7', '2018']
# ['Learn C++', 'EDUCATION', '4.6', '73404', '5300.0', '1000000', 'Free', '0.0', 'Everyone', 'Education', '2017-12-25', '4.5.2', '4.0 ', '25', '12', '2017']
# ['Learn JavaScript', 'EDUCATION', '4.6', '25183', '5400.0', '1000000', 'Free', '0.0', 'Everyone', 'Education', '2017-12-25', '5.7.2', '4.0 ', '25', '12', '2017']
# ['Learn Java', 'EDUCATION', '4.7', '52743', '5400.0', '1000000', 'Free', '0.0', 'Everyone', 'Education', '2017-12-25', '3.5.2', '4.0 ', '25', '12', '2017']
# ['Learn HTML', 'EDUCATION', '4.7', '61749', '5400.0', '1000000', 'Free', '0.0', 'Everyone', 'Education', '2017-12-25', '5.5.2', '4.0 ', '25', '12', '2017']
# ['Programming Hub, Learn to code', 'EDUCATION', '4.3', '55704', '15000.0', '1000000', 'Free', '0.0', 'Everyone', 'Education', '2018-08-04', '4.2.8', '4.1 ', '4', '8', '2018']
# ['Learn SQL', 'EDUCATION', '4.7', '19277', '5300.0', '1000000', 'Free', '0.0', 'Everyone', 'Education', '2017-12-25', '3.4.2', '4.0 ', '25', '12', '2017']
# ['Ready4 SAT (Prep4 SAT)', 'EDUCATION', '4.6', '13612', '48000.0', '100000', 'Free', '0.0', 'Everyone', 'Education', '2018-05-10', '7.2.3633', '4.4 ', '10', '5', '2018']
# ['Socratic - Math Answers & Homework Help', 'EDUCATION', '4.6', '37862', '5400.0', '1000000', 'Free', '0.0', 'Everyone', 'Education', '2018-06-07', '1.8.1', '4.1 ', '7', '6', '2018']
# ['Ready4 GMAT (Prep4 GMAT)', 'EDUCATION', '4.6', '18372', '47000.0', '100000', 'Free', '0.0', 'Everyone', 'Education', '2018-05-21', '7.2.3634', '4.4 ', '21', '5', '2018']
# ['Pocket GMAT Math', 'EDUCATION', '4.3', '656', '556.0', '10000', 'Free', '0.0', 'Everyone', 'Education', '2014-07-11', '1.1', '2.2 ', '11', '7', '2014']
# ['GMAT Question Bank', 'EDUCATION', '4.2', '240', '29000.0', '10000', 'Free', '0.0', 'Everyone', 'Education', '2015-04-29', '1.2.0', '2.3.3 ', '29', '4', '2015']
# ['GRE Tutor', 'EDUCATION', '4.0', '275', '2300.0', '50000', 'Free', '0.0', 'Everyone', 'Education', '2013-12-02', '2.9', '2.1 ', '2', '12', '2013']
# ['play2prep: ACT, SAT prep', 'EDUCATION', '4.2', '3692', '4400.0', '100000', 'Free', '0.0', 'Everyone', 'Education', '2015-07-23', '4.1.3', '2.3.3 ', '23', '7', '2015']
# ['SAT Test', 'EDUCATION', '4.1', '2363', '6600.0', '100000', 'Free', '0.0', 'Everyone', 'Education', '2016-11-17', '2.48', '4.0 ', '17', '11', '2016']
# ['Pocket SAT Math', 'EDUCATION', '4.0', '430', '526.0', '10000', 'Free', '0.0', 'Everyone', 'Education', '2014-07-11', '1.2', '2.1 ', '11', '7', '2014']
# ['TOEFL Prep & Practice from Magoosh', 'EDUCATION', '4.5', '756', '12000.0', '100000', 'Free', '0.0', 'Everyone', 'Education', '2018-06-18', '3.2.0', '4.1 ', '18', '6', '2018']
# ['GREÂ® Flashcards by Kaplan', 'EDUCATION', '4.0', '316', '29000.0', '50000', 'Free', '0.0', 'Everyone', 'Education', '2017-02-15', '1.4', '4.0 ', '15', '2', '2017']
# ['edX - Online Courses by Harvard, MIT & more', 'EDUCATION', '4.6', '32380', '10000.0', '1000000', 'Free', '0.0', 'Everyone 10+', 'Education', '2018-07-15', '2.15.1', '4.1 ', '15', '7', '2018']
# ['Rosetta Stone: Learn to Speak & Read New Languages', 'EDUCATION', '4.5', '172505', '76000.0', '5000000', 'Free', '0.0', 'Everyone', 'Education;Education', '2018-06-27', '5.2.1', '5.0 ', '27', '6', '2018']
# ['LinkedIn Learning: Online Courses to Learn Skills', 'EDUCATION', '4.6', '7973', '18000.0', '1000000', 'Free', '0.0', 'Everyone', 'Education', '2018-07-27', '0.29.74', '4.4 ', '27', '7', '2018']
# ['Babbel â€“ Learn Languages', 'EDUCATION', '4.3', '266935', '21000.0', '10000000', 'Free', '0.0', 'Everyone', 'Education', '2018-07-30', '20.7.2', '4.4 ', '30', '7', '2018']
# ['Free english course', 'EDUCATION', '4.7', '142632', '6900.0', '5000000', 'Free', '0.0', 'Everyone', 'Education', '2018-07-12', '2.8', '4.1 ', '12', '7', '2018']
# ['Learn 50 languages', 'EDUCATION', '4.4', '55256', '14000.0', '5000000', 'Free', '0.0', 'Everyone', 'Education', '2018-06-19', '10.9.1', '4.0 ', '19', '6', '2018']
# ['Rosetta Stone: Learn to Speak & Read New Languages', 'EDUCATION', '4.5', '172508', '76000.0', '5000000', 'Free', '0.0', 'Everyone', 'Education;Education', '2018-06-27', '5.2.1', '5.0 ', '27', '6', '2018']
# ['Babbel â€“ Learn Spanish', 'EDUCATION', '4.4', '54798', '11000.0', '1000000', 'Free', '0.0', 'Everyone', 'Education', '2018-07-30', '20.7.2', '4.4 ', '30', '7', '2018']
# ['Mango Languages: Lovable Language Courses', 'EDUCATION', '4.0', '4815', '19000.0', '500000', 'Free', '0.0', 'Everyone', 'Education', '2018-07-17', '4.2.3', '4.2 ', '17', '7', '2018']
# ['Learn English with Aco', 'EDUCATION', '4.6', '75112', '6500.0', '1000000', 'Free', '0.0', 'Everyone', 'Education', '2017-11-11', '2.09', '4.1 ', '11', '11', '2017']
# ['Learn to Speak English', 'EDUCATION', '4.4', '33646', '7000.0', '1000000', 'Free', '0.0', 'Everyone', 'Education', '2018-07-15', '2.3.9', '4.0 ', '15', '7', '2018']
# ['Learn English with Wlingua', 'EDUCATION', '4.7', '314300', '3300.0', '10000000', 'Free', '0.0', 'Everyone', 'Education', '2018-05-02', '1.94.9', '4.0 ', '2', '5', '2018']
# ['busuu: Learn Languages - Spanish, English & More', 'EDUCATION', '4.3', '206527', '21000.0', '10000000', 'Free', '0.0', 'Everyone 10+', 'Education', '2018-08-01', '13.9.0.161', '5.0 ', '1', '8', '2018']
# ['Study Checker', 'EDUCATION', '4.2', '3816', '2600.0', '500000', 'Free', '0.0', 'Everyone', 'Education', '2016-05-04', '3.6.0.115_FN', '2.3 ', '4', '5', '2016']
# ['My Study Life - School Planner', 'EDUCATION', '4.3', '47847', '21000.0', '1000000', 'Free', '0.0', 'Everyone', 'Education', '2017-06-13', '6.1.3', '4.0.3 ', '13', '6', '2017']
# ['HomeWork', 'EDUCATION', '4.3', '16195', '5200.0', '1000000', 'Free', '0.0', 'Everyone', 'Education', '2016-09-20', '8.5.2', '4.0 ', '20', '9', '2016']
# ['Next Gen Science Standards', 'EDUCATION', '4.3', '206', '18000.0', '50000', 'Free', '0.0', 'Everyone', 'Education', '2016-12-20', '1.12.1', '2.3 ', '20', '12', '2016']
# ["Teacher's Gradebook - Additio", 'EDUCATION', '4.2', '3241', '16000.0', '100000', 'Free', '0.0', 'Everyone', 'Education', '2018-08-01', '4.8.2', '4.0.3 ', '1', '8', '2018']
# ['Common Core', 'EDUCATION', '4.0', '835', '15000.0', '100000', 'Free', '0.0', 'Everyone', 'Education', '2016-12-20', '2.3.1', '2.3 ', '20', '12', '2016']
# ['Homework Planner', 'EDUCATION', '4.0', '2525', '1200.0', '100000', 'Free', '0.0', 'Everyone', 'Education', '2015-01-11', '15.9.4', '4.0 ', '11', '1', '2015']
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13556\2959245108.py in <module>
#       2 with open('data.csv','r') as file:
#       3     csv_file = csv.reader(file,delimiter=',')
# ----> 4     for ele in csv_file:
#       5         print(ele)
#
# C:\ProgramData\Anaconda3\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x8d in position 4081: character maps to <undefined>

# %% [markdown]
# #### 3. What modes do File objects for reader and writer objects need to be opened in?
# **Ans:** For `csv.reader(iterable_file_object)`, the file objects needed to be opened in `read` mode `mode='r'` Whereas for `csv.writer(iterable_file_object)` the file objects needed to be opened in `write` mode `mode='w'`

# %% [markdown]
# #### 4. What method takes a list argument and writes it to a CSV file?
# **Ans:** csv.writer class provides two methods for writing to CSV. They are `writerow()` and `writerows().` writerow() method writes a single row at a time. Whereas writerows() method is used to write multiple rows at a time.

# %%
import csv      
fields = ['Name', 'Branch', 'Year', 'CGPA'] #column names 
rows = [ 
            ['Remya', 'ECE', '2', '8.0'],  # data rows of csv file 
            ['Abhay', 'COE', '2', '7.1'], 
            ['Ramisha', 'IT', '2', '5.3']
       ] 
with open("university_records.csv", 'w') as csvfile: 
    csvwriter = csv.writer(csvfile) # creating a csv writer object 
    csvwriter.writerow(fields) # writing the fields 
    csvwriter.writerows(rows) # writing the data rows

# %% [markdown]
# #### 5. What do the keyword arguments delimiter and line terminator do?
# **Ans:** Lets take the example of a csv file:
# `First Name, Last Name, Age`
# `Remya, R S, 33`
# `Nimmy, James, 33`
# Here `','` is Delimiter. We can use any Character as per our needs if required. Similarly Line Terminator comes at end of line by default it is newline and can be changed accourding to Requirement.

# %% [markdown]
# #### 6. What function takes a string of JSON data and returns a Python data structure?
# **Ans:** `loads()` method takes a string of JSON data and returns a Python data structure

# %%
# Example of json.loads() method
import json
my_details_json ='''{
    "Name": "Remya R S",
    "Qualification": "MTech in ECE",
    "Stream": "Advanced ECE"
}'''
print(my_details_json)
print(f'Type of my_details_json is {type(my_details_json)}')
my_details = json.loads(my_details_json)
print(my_details)
print(f'Type of my_details is {type(my_details)}')
# Out:
# {
#     "Name": "Remya R S",
#     "Qualification": "MTech in ECE",
#     "Stream": "Advanced ECE"
# }
# Type of my_details_json is <class 'str'>
# {'Name': 'Remya R S', 'Qualification': 'MTech in ECE', 'Stream': 'Advanced ECE'}
# Type of my_details is <class 'dict'>

# %% [markdown]
# #### 7. What function takes a Python data structure and returns a string of JSON data?
# **Ans:** `dumps()` method takes a python data structure and returns a string of JSON data

# %%
# Example of json.dumps() method
import json
my_details = {
    "Name": "Remya R S",
    "Qualification": "MTech in ECE",
    "Stream": "Advanced ECE"
}
print(my_details)
print(f'Type of my_details is {type(my_details)}')
my_details_json = json.dumps(my_details, indent=4, sort_keys=True)
print(my_details_json)
print(f'Type of my_details_json is {type(my_details_json)}')
# Out:
# {'Name': 'Remya R S', 'Qualification': 'MTech in ECE', 'Stream': 'Advanced ECE'}
# Type of my_details is <class 'dict'>
# {
#     "Name": "Remya R S",
#     "Qualification": "MTech in ECE",
#     "Stream": "Advanced ECE"
# }
# Type of my_details_json is <class 'str'>
